# %% [markdown]
# ## Quick and dirty code, only used for rendering the different icons

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

tips = sns.load_dataset("tips")

fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

# %%
# Distplot plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")
np.random.seed(0)
x = np.random.randn(100)

ax = sns.distplot(x)

plt.savefig('seaborn_dist.svg')
plt.show()
plt.clf()

# %%
# Joint plot
# -----------------------------------------------------------------------------
sns.set_style("whitegrid")
penguins = sns.load_dataset("penguins")
ax = sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", height=0.8, kind="hex")

plt.savefig('seaborn_joint.svg')
plt.show()
plt.clf()
# Out:
# C:\Program Files\Python38\lib\site-packages\seaborn\axisgrid.py:1734: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   f.tight_layout()

# %%
# Kde plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")
np.random.seed(1)
X = 4 + np.random.normal(0,1.5,200)

sns.kdeplot(X)

plt.savefig('seaborn_kde.svg')
plt.show()
plt.clf()

# %%
# pairplot plot
# -----------------------------------------------------------------------------
sns.set_style("whitegrid")

penguins = sns.load_dataset("penguins")
ax = sns.pairplot(penguins,
                x_vars=["bill_length_mm", "bill_depth_mm"],
                y_vars=["bill_length_mm", "bill_depth_mm"],
                height=2, plot_kws=dict(marker="+", linewidth=0.2))
ax.fig.tight_layout()
plt.savefig('seaborn_pairplot.svg')
plt.show()
plt.clf()

# %%
# rug plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

sns.kdeplot(X)
sns.rugplot(X, height=.1)

plt.savefig('seaborn_rugplot.svg')
plt.show()
plt.clf()

# %%
# Bar plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

ax = sns.barplot(x="day", y="total_bill", data=tips)

plt.savefig('seaborn_bar.svg')
plt.show()
plt.clf()

# %%
# Count plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

ax = sns.countplot(x="day", data=tips)

plt.savefig('seaborn_count.svg')
plt.show()
plt.clf()

# %%
# Box plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

ax = sns.boxplot(x="day", y="total_bill", data=tips)

plt.savefig('seaborn_boxplot.svg')
plt.show()
plt.clf()

# %%
# violin plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

ax = sns.violinplot(x="day", y="total_bill", data=tips)

plt.savefig('seaborn_violinplot.svg')
plt.show()
plt.clf()

# %%
# Strip plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

ax = sns.stripplot(x="day", y="total_bill", data=tips)

plt.savefig('seaborn_stripplot.svg')
plt.show()
plt.clf()

# %%
# swarm plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(0.8,0.8))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")

ax = sns.swarmplot(x="day", y="total_bill", data=tips)

plt.savefig('seaborn_swarmplot.svg')
plt.show()
plt.clf()

# %%
# heatmap plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(1.5,1.5))
d = 0.01
ax = fig.add_axes([d,d,1-2*d,1-2*d])
sns.set_style("whitegrid")
tips_mx = tips.corr()
ax = sns.heatmap(tips_mx)

plt.savefig('seaborn_heatmap.svg')
plt.show()
plt.clf()

# %%
# clustermap plot
# -----------------------------------------------------------------------------
fig = plt.figure(figsize=(3,3))
sns.set_style("whitegrid")
tips_mx = tips.corr()
ax = sns.clustermap(tips_mx, figsize=(2.7,2.7))
plt.savefig('seaborn_clustermap.svg')
plt.show()
plt.clf()

# %%
# lmplot plot
# -----------------------------------------------------------------------------

plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"])

plt.savefig('seaborn_lmplot.svg')
plt.show()
plt.clf()

# %%
# Pairgrid plot
# -----------------------------------------------------------------------------
g = sns.PairGrid(penguins, diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)
plt.savefig('seaborn_pairgrid.svg')
plt.show()
plt.clf()

# %%
# facetgrid plot
# -----------------------------------------------------------------------------
g = sns.FacetGrid(tips, col="time", hue="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill", "Tip")
g.add_legend()

plt.savefig('seaborn_facetgrid.svg')
plt.show()
plt.clf()
